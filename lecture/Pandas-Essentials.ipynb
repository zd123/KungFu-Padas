# %%
import pandas as pd

# %%
# READ IN A DATA FILE
df = pd.read_csv('lecture-data/city-of-chicago-salaries.csv')

# %%
# Print first 5 columns
df.head(5)

# Print last 5 columns
df.tail(5)
# Out:
#                       Name                  Position Title        Department  \
# 32049  ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32050   ZYGOWICZ,  PETER J                  POLICE OFFICER            POLICE
# 32051    ZYMANTAS,  MARK E                  POLICE OFFICER            POLICE
# 32052  ZYRKOWSKI,  CARLO E                  POLICE OFFICER            POLICE
# 32053  ZYSKOWSKI,  DARIUSZ         CHIEF DATA BASE ANALYST              DoIT
#
#        Employee Annual Salary
# 32049                 96553.6
# 32050                 78012.0
# 32051                 78012.0
# 32052                 80724.0
# 32053                110352.0
#
# [5 rows x 4 columns]

# %%
# Print the type of data in each column (ie, float, int or string...)
df.info()

# Print a description of the dataframe
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32054 entries, 0 to 32053
# Data columns (total 4 columns):
# Name                      32054 non-null object
# Position Title            32054 non-null object
# Department                32054 non-null object
# Employee Annual Salary    32054 non-null object
# dtypes: object(4)
#                        Name  Position Title Department Employee Annual Salary
# count                 32054           32054      32054                  32054
# unique                31795            1098         35                   1097
# top     RODRIGUEZ,  RICHARD  POLICE OFFICER     POLICE              $78012.00
# freq                      4            9432      13623                   2750
#
# [4 rows x 4 columns]

# %%
# Select one column
df['Name']
# or...
df.Name
# Out:
# 0            AARON,  ELVIA J
# 1          AARON,  JEFFERY M
# 2        AARON,  KIMBERLEI R
# 3        ABAD JR,  VICENTE M
# 4      ABBATACOLA,  ROBERT J
# 5      ABBATEMARCO,  JAMES J
# 6           ABBATE,  TERRY M
# 7           ABBOTT,  BETTY L
# 8          ABBOTT,  LYNISE M
# 9     ABBRUZZESE,  WILLIAM J
# 10           ABDALLAH,  ZAID
# 11     ABDELHADI,  ABDALMAHD
# 12       ABDELLATIF,  AREF R
# 13        ABDELMAJEID,  AZIZ
# 14        ABDELQAWI,  YOSEPH
# ...
# 32039            ZUREK,  MARY H
# 32040           ZVANJA,  TINA M
# 32041    ZWARYCZ MANN,  IRENE A
# 32042        ZWARYCZ,  THOMAS J
# 32043        ZWIESLER,  MATTHEW
# 32044          ZWIT,  JEFFREY J
# 32045       ZWOLFER,  MATTHEW W
# 32046          ZWOLSKI,  MARY L
# 32047             ZYDEK,  BRYAN
# 32048          ZYGADLO,  JOHN P
# 32049       ZYGADLO,  MICHAEL J
# 32050        ZYGOWICZ,  PETER J
# 32051         ZYMANTAS,  MARK E
# 32052       ZYRKOWSKI,  CARLO E
# 32053       ZYSKOWSKI,  DARIUSZ
# Name: Name, Length: 32054, dtype: object

# %%
# Select more than one column
df[['Name', 'Department']]
# Out:
#                         Name        Department
# 0            AARON,  ELVIA J       WATER MGMNT
# 1          AARON,  JEFFERY M            POLICE
# 2        AARON,  KIMBERLEI R  GENERAL SERVICES
# 3        ABAD JR,  VICENTE M       WATER MGMNT
# 4      ABBATACOLA,  ROBERT J          AVIATION
# 5      ABBATEMARCO,  JAMES J              FIRE
# 6           ABBATE,  TERRY M            POLICE
# 7           ABBOTT,  BETTY L  FAMILY & SUPPORT
# 8          ABBOTT,  LYNISE M            POLICE
# 9     ABBRUZZESE,  WILLIAM J              IPRA
# 10           ABDALLAH,  ZAID            POLICE
# 11     ABDELHADI,  ABDALMAHD            POLICE
# 12       ABDELLATIF,  AREF R              FIRE
# 13        ABDELMAJEID,  AZIZ            POLICE
# 14        ABDELQAWI,  YOSEPH              OEMC
# 15       ABDOLLAHZADEH,  ALI              FIRE
# 16  ABDUL-KARIM,  MUHAMMAD A       WATER MGMNT
# 17          ABDULLAH,  ASKIA      CITY COUNCIL
# 18       ABDULLAH,  DANIEL N              FIRE
# 19          ABDULLAH,  KEVIN              FIRE
# 20      ABDULLAH,  LAKENYA N            POLICE
# 21       ABDULLAH,  RASHAD J  GENERAL SERVICES
# 22         ABEJERO,  JASON V            POLICE
# 23         ABELS,  KENNETH L      CITY COUNCIL
# 24     ABERCROMBIE,  TIMOTHY     STREETS & SAN
# 25    ABOUELKHEIR,  HASSAN A  FAMILY & SUPPORT
# 26        ABRAHAM,  GIRLEY T       WATER MGMNT
# 27        ABRAHAM,  GODWIN K  BUSINESS AFFAIRS
# 28     ABRAMAVICIUS,  ANNA A              OEMC
# 29       ABRAMS,  DANIELLE T     STREETS & SAN
# 30          ABRAMS,  HENRY L            POLICE
# 31         ABRAMSKI,  JOHN E              FIRE
# 32       ABRATANSKI,  MARK A              FIRE
# 33             ABREU,  DILAN       WATER MGMNT
# 34             ABREU,  EDWIN     STREETS & SAN
# 35         ABREU,  ROBERTO J        TRANSPORTN
# 36            ABREU,  ROSITA            HEALTH
# 37            ABREU,  VICTOR  FAMILY & SUPPORT
# 38            ABREU,  VICTOR              FIRE
# 39             ABRON,  FLOYD            POLICE
# 40        ABRONS,  KENNETH L          AVIATION
# 41          ABSTON,  KATHY A            POLICE
# 42     ABUBAKER,  MOHAMMED G            HEALTH
# 43        ABUTALEB,  AHMAD H       WATER MGMNT
# 44      ABUZANAT,  ABDALLA H            POLICE
# 45        ACCARDI,  JOHNNA L     STREETS & SAN
# 46       ACCARDO,  ANTHONY D       WATER MGMNT
# 47      ACCARDO,  JENNIFER A            POLICE
# 48        ACCARDO,  ROSEMARY            POLICE
# 49        ACCARDO,  THOMAS J            POLICE
# 50       ACCIARI,  MICHAEL G     STREETS & SAN
# 51      ACCIARI,  NICHOLAS B     STREETS & SAN
# 52          ACCURSO,  MARY K    MAYOR'S OFFICE
# 53         ACEVEDO,  AARON F            POLICE
# 54     ACEVEDO,  ALEJANDRO R            POLICE
# 55      ACEVEDO,  BIENVENIDO            POLICE
# 56        ACEVEDO,  CLARISSA            POLICE
# 57          ACEVEDO,  DAILHA            HEALTH
# 58          ACEVEDO,  EDWARD            POLICE
# 59         ACEVEDO,  EDWIN C              FIRE
#                          ...               ...
#
# [32054 rows x 2 columns]

# %%
# Select the first 10 rows
df[0:10]

# Select the 9th row to the 21st row
df[9:21]

# Select the first 10 rows just of the column Name
df[0:10]['Name']

# Select the first 10 rows of the columns Name and "Employee Annual Salary"
df[0:10][['Name',"Employee Annual Salary"]]
# Out:
#                      Name  Employee Annual Salary
# 0         AARON,  ELVIA J                   85512
# 1       AARON,  JEFFERY M                   75372
# 2     AARON,  KIMBERLEI R                   80916
# 3     ABAD JR,  VICENTE M                   99648
# 4   ABBATACOLA,  ROBERT J                   89440
# 5   ABBATEMARCO,  JAMES J                   78012
# 6        ABBATE,  TERRY M                   80724
# 7        ABBOTT,  BETTY L                    2756
# 8       ABBOTT,  LYNISE M                   41784
# 9  ABBRUZZESE,  WILLIAM J                   62832
#
# [10 rows x 2 columns]

# %%
# Rename Columns
df.columns = ['Name', 'Job', 'Department', 'Salary']
df.head()
# Out:
#                     Name                       Job        Department  Salary
# 0        AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT   85512
# 1      AARON,  JEFFERY M            POLICE OFFICER            POLICE   75372
# 2    AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES   80916
# 3    ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT   99648
# 4  ABBATACOLA,  ROBERT J       ELECTRICAL MECHANIC          AVIATION   89440
#
# [5 rows x 4 columns]

# %%
# Create a new column
df['My New Column'] = "F the Police"
df
# Out:
#                         Name  \
# 0            AARON,  ELVIA J
# 1          AARON,  JEFFERY M
# 2        AARON,  KIMBERLEI R
# 3        ABAD JR,  VICENTE M
# 4      ABBATACOLA,  ROBERT J
# 5      ABBATEMARCO,  JAMES J
# 6           ABBATE,  TERRY M
# 7           ABBOTT,  BETTY L
# 8          ABBOTT,  LYNISE M
# 9     ABBRUZZESE,  WILLIAM J
# 10           ABDALLAH,  ZAID
# 11     ABDELHADI,  ABDALMAHD
# 12       ABDELLATIF,  AREF R
# 13        ABDELMAJEID,  AZIZ
# 14        ABDELQAWI,  YOSEPH
# 15       ABDOLLAHZADEH,  ALI
# 16  ABDUL-KARIM,  MUHAMMAD A
# 17          ABDULLAH,  ASKIA
# 18       ABDULLAH,  DANIEL N
# 19          ABDULLAH,  KEVIN
# 20      ABDULLAH,  LAKENYA N
# 21       ABDULLAH,  RASHAD J
# 22         ABEJERO,  JASON V
# 23         ABELS,  KENNETH L
# 24     ABERCROMBIE,  TIMOTHY
# 25    ABOUELKHEIR,  HASSAN A
# 26        ABRAHAM,  GIRLEY T
# 27        ABRAHAM,  GODWIN K
# 28     ABRAMAVICIUS,  ANNA A
# 29       ABRAMS,  DANIELLE T
# 30          ABRAMS,  HENRY L
# 31         ABRAMSKI,  JOHN E
# 32       ABRATANSKI,  MARK A
# 33             ABREU,  DILAN
# 34             ABREU,  EDWIN
# 35         ABREU,  ROBERTO J
# 36            ABREU,  ROSITA
# 37            ABREU,  VICTOR
# 38            ABREU,  VICTOR
# 39             ABRON,  FLOYD
# 40        ABRONS,  KENNETH L
# 41          ABSTON,  KATHY A
# 42     ABUBAKER,  MOHAMMED G
# 43        ABUTALEB,  AHMAD H
# 44      ABUZANAT,  ABDALLA H
# 45        ACCARDI,  JOHNNA L
# 46       ACCARDO,  ANTHONY D
# 47      ACCARDO,  JENNIFER A
# 48        ACCARDO,  ROSEMARY
# 49        ACCARDO,  THOMAS J
# 50       ACCIARI,  MICHAEL G
# 51      ACCIARI,  NICHOLAS B
# 52          ACCURSO,  MARY K
# 53         ACEVEDO,  AARON F
# 54     ACEVEDO,  ALEJANDRO R
# 55      ACEVEDO,  BIENVENIDO
# 56        ACEVEDO,  CLARISSA
# 57          ACEVEDO,  DAILHA
# 58          ACEVEDO,  EDWARD
# 59         ACEVEDO,  EDWIN C
#                          ...
#
#                                                  Job        Department  \
# 0                                   WATER RATE TAKER       WATER MGMNT
# 1                                     POLICE OFFICER            POLICE
# 2                           CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 3                                  CIVIL ENGINEER IV       WATER MGMNT
# 4                                ELECTRICAL MECHANIC          AVIATION
# 5                                        FIREFIGHTER              FIRE
# 6                                     POLICE OFFICER            POLICE
# 7                                 FOSTER GRANDPARENT  FAMILY & SUPPORT
# 8                                          CLERK III            POLICE
# 9                             INVESTIGATOR - IPRA II              IPRA
# 10                                    POLICE OFFICER            POLICE
# 11                                    POLICE OFFICER            POLICE
# 12     FIREFIGHTER (PER ARBITRATORS AWARD)-PARAMEDIC              FIRE
# 13                                    POLICE OFFICER            POLICE
# 14                       TRAFFIC CONTROL AIDE-HOURLY              OEMC
# 15                                         PARAMEDIC              FIRE
# 16                         ENGINEERING TECHNICIAN VI       WATER MGMNT
# 17                                  LEGISLATIVE AIDE      CITY COUNCIL
# 18                                   FIREFIGHTER-EMT              FIRE
# 19                                        LIEUTENANT              FIRE
# 20                                    CROSSING GUARD            POLICE
# 21           ELECTRICAL MECHANIC-AUTO-POLICE MTR MNT  GENERAL SERVICES
# 22                                    POLICE OFFICER            POLICE
# 23                              ASST TO THE ALDERMAN      CITY COUNCIL
# 24                                MOTOR TRUCK DRIVER     STREETS & SAN
# 25                         SENIOR PROGRAMMER/ANALYST  FAMILY & SUPPORT
# 26                                 CIVIL ENGINEER IV       WATER MGMNT
# 27                          ENGINEERING TECHNICIAN V  BUSINESS AFFAIRS
# 28                  SUPERVISING TRAFFIC CONTROL AIDE              OEMC
# 29                                SANITATION LABORER     STREETS & SAN
# 30                                    POLICE OFFICER            POLICE
# 31                               AMBULANCE COMMANDER              FIRE
# 32                                   FIREFIGHTER-EMT              FIRE
# 33                                  SEWER BRICKLAYER       WATER MGMNT
# 34                                      TREE TRIMMER     STREETS & SAN
# 35                          TRAFFIC SIGNAL REPAIRMAN        TRANSPORTN
# 36                     PERSONAL COMPUTER OPERATOR II            HEALTH
# 37                                  SENIOR COMPANION  FAMILY & SUPPORT
# 38                                   FIREFIGHTER-EMT              FIRE
# 39                                    POLICE OFFICER            POLICE
# 40                               ELECTRICAL MECHANIC          AVIATION
# 41                                    POLICE OFFICER            POLICE
# 42                    SENIOR ENVIRONMENTAL INSPECTOR            HEALTH
# 43                                 CIVIL ENGINEER II       WATER MGMNT
# 44  POLICE OFFICER (ASSIGNED AS EVIDENCE TECHNICIAN)            POLICE
# 45                                MOTOR TRUCK DRIVER     STREETS & SAN
# 46                              CONSTRUCTION LABORER       WATER MGMNT
# 47                                    POLICE OFFICER            POLICE
# 48                                    POLICE OFFICER            POLICE
# 49                                    POLICE OFFICER            POLICE
# 50                           DIVISION SUPERINTENDENT     STREETS & SAN
# 51                                MOTOR TRUCK DRIVER     STREETS & SAN
# 52                   ASST ADMINISTRATIVE SECRETARY I    MAYOR'S OFFICE
# 53                                    POLICE OFFICER            POLICE
# 54                                    POLICE OFFICER            POLICE
# 55                                    POLICE OFFICER            POLICE
# 56                                    POLICE OFFICER            POLICE
# 57      COMMUNICABLE DISEASE CONTROL INVESTIGATOR II            HEALTH
# 58                                    POLICE OFFICER            POLICE
# 59                                       FIREFIGHTER              FIRE
#                                                  ...               ...
#
#       Salary My New Column
# 0    85512.0  F the Police
# 1    75372.0  F the Police
# 2    80916.0  F the Police
# 3    99648.0  F the Police
# 4    89440.0  F the Police
# 5    78012.0  F the Police
# 6    80724.0  F the Police
# 7     2756.0  F the Police
# 8    41784.0  F the Police
# 9    62832.0  F the Police
# 10   43104.0  F the Police
# 11   75372.0  F the Police
# 12   87792.0  F the Police
# 13   75372.0  F the Police
# 14   19167.2  F the Police
# 15   75372.0  F the Police
# 16   96384.0  F the Police
# 17   25008.0  F the Police
# 18   81906.0  F the Police
# 19  102978.0  F the Police
# 20   16286.4  F the Police
# 21   89440.0  F the Police
# 22   78012.0  F the Police
# 23   52008.0  F the Police
# 24   70408.0  F the Police
# 25   99648.0  F the Police
# 26   99648.0  F the Police
# 27   91980.0  F the Police
# 28   54432.0  F the Police
# 29   69576.0  F the Police
# 30   86130.0  F the Police
# 31  115644.0  F the Police
# 32   79140.0  F the Police
# 33   86486.4  F the Police
# 34   71572.8  F the Police
# 35   93288.0  F the Police
# 36   57828.0  F the Police
# 37    2756.0  F the Police
# 38   84762.0  F the Police
# 39   80724.0  F the Police
# 40   89440.0  F the Police
# 41   80724.0  F the Police
# 42   69648.0  F the Police
# 43   83640.0  F the Police
# 44   84756.0  F the Police
# 45   70408.0  F the Police
# 46   76960.0  F the Police
# 47   75372.0  F the Police
# 48   86130.0  F the Police
# 49   78012.0  F the Police
# 50  102246.0  F the Police
# 51   71468.8  F the Police
# 52   44004.0  F the Police
# 53   71748.0  F the Police
# 54   75372.0  F the Police
# 55   78012.0  F the Police
# 56   86130.0  F the Police
# 57   49788.0  F the Police
# 58   75372.0  F the Police
# 59   83982.0  F the Police
#          ...           ...
#
# [32054 rows x 5 columns]

# %%
# Delete or 'drop' a column
df = df.drop("My New Column", axis=1)
df
# Out:
#                         Name  \
# 0            AARON,  ELVIA J
# 1          AARON,  JEFFERY M
# 2        AARON,  KIMBERLEI R
# 3        ABAD JR,  VICENTE M
# 4      ABBATACOLA,  ROBERT J
# 5      ABBATEMARCO,  JAMES J
# 6           ABBATE,  TERRY M
# 7           ABBOTT,  BETTY L
# 8          ABBOTT,  LYNISE M
# 9     ABBRUZZESE,  WILLIAM J
# 10           ABDALLAH,  ZAID
# 11     ABDELHADI,  ABDALMAHD
# 12       ABDELLATIF,  AREF R
# 13        ABDELMAJEID,  AZIZ
# 14        ABDELQAWI,  YOSEPH
# 15       ABDOLLAHZADEH,  ALI
# 16  ABDUL-KARIM,  MUHAMMAD A
# 17          ABDULLAH,  ASKIA
# 18       ABDULLAH,  DANIEL N
# 19          ABDULLAH,  KEVIN
# 20      ABDULLAH,  LAKENYA N
# 21       ABDULLAH,  RASHAD J
# 22         ABEJERO,  JASON V
# 23         ABELS,  KENNETH L
# 24     ABERCROMBIE,  TIMOTHY
# 25    ABOUELKHEIR,  HASSAN A
# 26        ABRAHAM,  GIRLEY T
# 27        ABRAHAM,  GODWIN K
# 28     ABRAMAVICIUS,  ANNA A
# 29       ABRAMS,  DANIELLE T
# 30          ABRAMS,  HENRY L
# 31         ABRAMSKI,  JOHN E
# 32       ABRATANSKI,  MARK A
# 33             ABREU,  DILAN
# 34             ABREU,  EDWIN
# 35         ABREU,  ROBERTO J
# 36            ABREU,  ROSITA
# 37            ABREU,  VICTOR
# 38            ABREU,  VICTOR
# 39             ABRON,  FLOYD
# 40        ABRONS,  KENNETH L
# 41          ABSTON,  KATHY A
# 42     ABUBAKER,  MOHAMMED G
# 43        ABUTALEB,  AHMAD H
# 44      ABUZANAT,  ABDALLA H
# 45        ACCARDI,  JOHNNA L
# 46       ACCARDO,  ANTHONY D
# 47      ACCARDO,  JENNIFER A
# 48        ACCARDO,  ROSEMARY
# 49        ACCARDO,  THOMAS J
# 50       ACCIARI,  MICHAEL G
# 51      ACCIARI,  NICHOLAS B
# 52          ACCURSO,  MARY K
# 53         ACEVEDO,  AARON F
# 54     ACEVEDO,  ALEJANDRO R
# 55      ACEVEDO,  BIENVENIDO
# 56        ACEVEDO,  CLARISSA
# 57          ACEVEDO,  DAILHA
# 58          ACEVEDO,  EDWARD
# 59         ACEVEDO,  EDWIN C
#                          ...
#
#                                                  Job        Department  \
# 0                                   WATER RATE TAKER       WATER MGMNT
# 1                                     POLICE OFFICER            POLICE
# 2                           CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 3                                  CIVIL ENGINEER IV       WATER MGMNT
# 4                                ELECTRICAL MECHANIC          AVIATION
# 5                                        FIREFIGHTER              FIRE
# 6                                     POLICE OFFICER            POLICE
# 7                                 FOSTER GRANDPARENT  FAMILY & SUPPORT
# 8                                          CLERK III            POLICE
# 9                             INVESTIGATOR - IPRA II              IPRA
# 10                                    POLICE OFFICER            POLICE
# 11                                    POLICE OFFICER            POLICE
# 12     FIREFIGHTER (PER ARBITRATORS AWARD)-PARAMEDIC              FIRE
# 13                                    POLICE OFFICER            POLICE
# 14                       TRAFFIC CONTROL AIDE-HOURLY              OEMC
# 15                                         PARAMEDIC              FIRE
# 16                         ENGINEERING TECHNICIAN VI       WATER MGMNT
# 17                                  LEGISLATIVE AIDE      CITY COUNCIL
# 18                                   FIREFIGHTER-EMT              FIRE
# 19                                        LIEUTENANT              FIRE
# 20                                    CROSSING GUARD            POLICE
# 21           ELECTRICAL MECHANIC-AUTO-POLICE MTR MNT  GENERAL SERVICES
# 22                                    POLICE OFFICER            POLICE
# 23                              ASST TO THE ALDERMAN      CITY COUNCIL
# 24                                MOTOR TRUCK DRIVER     STREETS & SAN
# 25                         SENIOR PROGRAMMER/ANALYST  FAMILY & SUPPORT
# 26                                 CIVIL ENGINEER IV       WATER MGMNT
# 27                          ENGINEERING TECHNICIAN V  BUSINESS AFFAIRS
# 28                  SUPERVISING TRAFFIC CONTROL AIDE              OEMC
# 29                                SANITATION LABORER     STREETS & SAN
# 30                                    POLICE OFFICER            POLICE
# 31                               AMBULANCE COMMANDER              FIRE
# 32                                   FIREFIGHTER-EMT              FIRE
# 33                                  SEWER BRICKLAYER       WATER MGMNT
# 34                                      TREE TRIMMER     STREETS & SAN
# 35                          TRAFFIC SIGNAL REPAIRMAN        TRANSPORTN
# 36                     PERSONAL COMPUTER OPERATOR II            HEALTH
# 37                                  SENIOR COMPANION  FAMILY & SUPPORT
# 38                                   FIREFIGHTER-EMT              FIRE
# 39                                    POLICE OFFICER            POLICE
# 40                               ELECTRICAL MECHANIC          AVIATION
# 41                                    POLICE OFFICER            POLICE
# 42                    SENIOR ENVIRONMENTAL INSPECTOR            HEALTH
# 43                                 CIVIL ENGINEER II       WATER MGMNT
# 44  POLICE OFFICER (ASSIGNED AS EVIDENCE TECHNICIAN)            POLICE
# 45                                MOTOR TRUCK DRIVER     STREETS & SAN
# 46                              CONSTRUCTION LABORER       WATER MGMNT
# 47                                    POLICE OFFICER            POLICE
# 48                                    POLICE OFFICER            POLICE
# 49                                    POLICE OFFICER            POLICE
# 50                           DIVISION SUPERINTENDENT     STREETS & SAN
# 51                                MOTOR TRUCK DRIVER     STREETS & SAN
# 52                   ASST ADMINISTRATIVE SECRETARY I    MAYOR'S OFFICE
# 53                                    POLICE OFFICER            POLICE
# 54                                    POLICE OFFICER            POLICE
# 55                                    POLICE OFFICER            POLICE
# 56                                    POLICE OFFICER            POLICE
# 57      COMMUNICABLE DISEASE CONTROL INVESTIGATOR II            HEALTH
# 58                                    POLICE OFFICER            POLICE
# 59                                       FIREFIGHTER              FIRE
#                                                  ...               ...
#
#       Salary
# 0    85512.0
# 1    75372.0
# 2    80916.0
# 3    99648.0
# 4    89440.0
# 5    78012.0
# 6    80724.0
# 7     2756.0
# 8    41784.0
# 9    62832.0
# 10   43104.0
# 11   75372.0
# 12   87792.0
# 13   75372.0
# 14   19167.2
# 15   75372.0
# 16   96384.0
# 17   25008.0
# 18   81906.0
# 19  102978.0
# 20   16286.4
# 21   89440.0
# 22   78012.0
# 23   52008.0
# 24   70408.0
# 25   99648.0
# 26   99648.0
# 27   91980.0
# 28   54432.0
# 29   69576.0
# 30   86130.0
# 31  115644.0
# 32   79140.0
# 33   86486.4
# 34   71572.8
# 35   93288.0
# 36   57828.0
# 37    2756.0
# 38   84762.0
# 39   80724.0
# 40   89440.0
# 41   80724.0
# 42   69648.0
# 43   83640.0
# 44   84756.0
# 45   70408.0
# 46   76960.0
# 47   75372.0
# 48   86130.0
# 49   78012.0
# 50  102246.0
# 51   71468.8
# 52   44004.0
# 53   71748.0
# 54   75372.0
# 55   78012.0
# 56   86130.0
# 57   49788.0
# 58   75372.0
# 59   83982.0
#          ...
#
# [32054 rows x 4 columns]

# %%
# Duplicate a column
df['NameDupe'] = df['Name']
df
# Drop that column cause its stupid
df = df.drop('NameDupe', axis=1)

# %% [markdown]
# # BASIC MATH STUFF

# %%
salMean = df.Salary.mean()
# Out:
# 75070.385710364077

# %% [markdown]
# # DICTIONARIES AND DATAFRAMES

# %%
# Put a Python Dictionary into a data series 
d = {'Chicago': 1000, 'New York': 1300, 'Portland': 900, 'San Francisco': 1100,
     'Austin': 450, 'Boston': None}
cities = pd.Series(d)
cities

df_cities = pd.DataFrame(cities)
df_cities
# Out:
#                   0
# Austin          450
# Boston          NaN
# Chicago        1000
# New York       1300
# Portland        900
# San Francisco  1100
#
# [6 rows x 1 columns]

# %%
# LOADING A MORE COMPLEX DICTIONARY INTO A PANADAS DATAFRAME

data = {'year': [2010, 2011, 2012, 2011, 2012, 2010, 2011, 2012],
        'team': ['Bears', 'Bears', 'Bears', 'Packers', 'Packers', 'Lions', 'Lions', 'Lions'],
        'wins': [11, 8, 10, 15, 11, 6, 10, 4],
        'losses': [5, 8, 6, 1, 5, 10, 6, 12]}
# football = pd.DataFrame(data, columns=['year', 'team', 'wins', 'losses'])
football = pd.DataFrame(data, columns=data.keys())
football
# Out:
#    losses  wins     team  year
# 0       5    11    Bears  2010
# 1       8     8    Bears  2011
# 2       6    10    Bears  2012
# 3       1    15  Packers  2011
# 4       5    11  Packers  2012
# 5      10     6    Lions  2010
# 6       6    10    Lions  2011
# 7      12     4    Lions  2012
#
# [8 rows x 4 columns]

# %%
# Out:
#                   0
# Austin          450
# Boston          NaN
# Chicago        1000
# New York       1300
# Portland        900
# San Francisco  1100
#
# [6 rows x 1 columns]

# %%
### THIS IS REALLY GOOD SHIT ON APPLYING FUCNTIONS A PANDAS DATAFRAME 
### BUT IS WAY TO COMPLICATED FOR 101, GONNA PUT IT AT THE BOTTM AND MAYBE SOMEONE WILL ENJOY IT

# # lambda x: float(x.replace('$', ''))
# # myLambda = lambda x: x.replace('$', '')
# def myDef(x):
#     x = x.replace('$','')
#     return x

# # df['Employee Annual Salary'].apply(lambda x: x.replace('$', ''))
# # df['Employee Annual Salary'].apply(myLambda)
# df['Employee Annual Salary'].apply(myDef)
